# %%
#W2A1
print("Hello, World!")
# Out:
# Hello, World!

# %%
#W2A2
n=str(input("Nhập tên của bạn: "))
print('Xin chào',n)
# Out:
# Xin chào Hong

# %%
#W2A3
a, b = map(int, input().split())
tong = a + b
hieu = a - b
tich = a * b
phan_nguyen = a // b
phan_du = a % b
chia_thuc = a / b
print("Tong =", tong)
print("Hieu =", hieu)
print("Tich =", tich)
print("Phan nguyen =", phan_nguyen)
print("Phan du =", phan_du)
print("Chia thuc = {:.2f}".format(chia_thuc))
# Out:
# Tong = 13
# Hieu = -1
# Tich = 42
# Phan nguyen = 0
# Phan du = 6
# Chia thuc = 0.86

# %%
#W2A4
a1,b1,c1,a2,b2,a3=map(float,input("nhap 6 diem cach nhau bang dau cach: ").split())
TB=((a1+b1+c1)+(a2+b2)*2+a3*3)/10
print(round(TB,1))
# Out:
# 7.4

# %%
#W2A5
a,b=map(int,input('nhập hai số nguyên cách nhau bởi dấu cách: ').split())
print(a**b)
# Out:
# 16

# %%
#W2A6
a=input('nhập kí tự: ')
print('unicode: ', ord(a))
print('chữ cái hoa tương ứng: ', a.upper())
# Out:
# unicode:  103
# chữ cái hoa tương ứng:  G

# %%
#Vi du
print("### # # ### ### \n # # # # # \n # # # # # \n # # # # # \n # # # # # ")
# Out:
# ### # # ### ###
#  # # # # #
#  # # # # #
#  # # # # #
#  # # # # #

# %%
#Vi du
a,b,c=map(int,input("nhap 3 canh cach nhau bang dau cach: ").split())
if a+b>c and a+c>b and b+c>a:
    if a==b==c:
       print("tam giac deu")
    elif a==b or b==c or a==c:
         print("tam giac can")
    else:
        print("tam giac thuong")
else:
    print("khong phai tam giac")
# Out:
# tam giac thuong

# %%
#W2A7
A = ((13 ** 2) * 3) + 5
B = 13**2 * 3 + 5
print("A =", A)
print("B =", B)
# Out:
# A = 512
# B = 512

# %%
#W2A8
n=input("nhap nhiet do theo thang C: ")
f=(9/5)*int(n)+32
print("Nhiet do theo thang F la: ",f)
# Out:
# Nhiet do theo thang F la:  41.0

# %%
#W2A9
x = float(input())
phi_vc = 10
thue = x * 0.40  # 30% + 10%
tong = x + phi_vc + thue
print("{:.2f}".format(tong))
# Out:
# 990.00

# %%
#W2A10
a, b, c = input().split()
print(f"Hi {c}, {b} and {a}.")
# Out:
# Hi Bich, Lien and Hong.

# %%
#W2A11
h = int(input())
m = int(input())
seconds = h * 3600 + m * 60
print(seconds)
# Out:
# 22080

# %%
#W2A12
n = int(input())
stickers = 6 * (n ** 2)
print(stickers)
# Out:
# 294

# %%
#W2A13
a = int(input())
b = int(input())
result = (a * b) % 10
print(result)
# Out:
# 0

# %%
#W2A14
a = int(input())
b = int(input())
a = a + b
b = a - b
a = a - b
print(a, b)
# Out:
# 5 7

# %%
#W2A15
n=int(input("Nhap n: "))
so_sao = 6*n*(n-1)+1
print("so sao thu", n, "la: ", so_sao)
# Out:
# so sao thu 10 la:  541

# %%
#W2A16
print("Spring")
print("Summer")
print("Autumn")
print("Winter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
print("  *  ")
print(" *** ")
print("*****")
# Out:
#   *
#  ***
# *****

# %%
#W2A18
print("###   ##    ### ###")
print(" #    # #    #   #")
print(" #    #  #   #   #")
print(" #    #  #   #   #")
print(" #    # #    #   #")
# Out:
# ###   ##    ### ###
#  #    # #    #   #
#  #    #  #   #   #
#  #    #  #   #   #
#  #    # #    #   #

# %%
#W2A19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print("January")
print("February")
print("March")
print("April")
print("May")
print("June")
print("July")
print("August")
print("September")
print("October")
print("November")
print("December")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
for _ in range(10):
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
