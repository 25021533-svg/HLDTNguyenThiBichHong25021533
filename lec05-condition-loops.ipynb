# %%
data = [10, 20, 30, 40, 50,76]
result = average = sum(data) / len(data)
print(f"Trung bình cộng: {result}")
# Out:
# Trung bình cộng: 37.666666666666664

# %%
list_a=(int(item) for item in input().split())
def average(list_a):
    for x in list_a:
        total += int(x)
    return total(list_a) / len(list_a)

# %%
nums=    list(range(1, 11))
print(nums)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 nums=list(range(1, 11))
#       2 print(nums)
#
# TypeError: 'list' object is not callable

# %%
s = 0
for x in range(1, 5):
    s += x
print(s)
# Out:
# 10

# %%
a = [1, 2, 3]
for x in a:
    x = x * 2
print(a)
# Out:
# [1, 2, 3]

# %%
table = [[2,1,0],[3,5,2],[4,0,1]]
print(sum(row[0] for row in table))
# Out:
# 9

# %%
count = 0
for _ in range(5):
    count += 1
