# %%
#Program Flow and Variables (biến cục bộ, biến toàn cục)
a=1
if a==0:
    b=a+1
    print(b)

# %%
#Multiple choices (if-else lồng nhau, bậc thang đi xuống)
a=int(input("điem so"))
if a>=90:
    print("Excellent")
else:
    if 90>a>=70:
        print("Good")
    else: 
        if 70>a>=50:
            print("Average")
        else:
            print("Fail")
# Out:
# Average

# %%
list=[3,5,2,8,6]
print(list[0])
# Out:
# 3
