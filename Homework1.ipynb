# %%
#Bài 1
n = int(input("Nhập số nguyên n: "))
print("Số gấp đôi của n là:", 2 * n)
# Out:
# Số gấp đôi của n là: 8

# %%
#Bài 2
a = float(input("Nhập chiều rộng a: "))
b = float(input("Nhập chiều dài b: "))
pi = 3.14
r = min(a, b) / 2
dien_tich_dat = a * b
dien_tich_hinh_tron = pi * (r ** 2)
dien_tich_trong_cay = dien_tich_dat - dien_tich_hinh_tron
print("Diện tích trồng cây là:", round(dien_tich_trong_cay, 2))
# Out:
# Diện tích trồng cây là: 11.44

# %%
c = input("Nhập một ký tự: ")
if c.isupper():
        print("Chữ thường tương ứng:", c.lower())
elif c.islower():
        print("Chữ hoa tương ứng:", c.upper())
else:
        print("Không phải chữ cái.")
# Out:
# Chữ hoa tương ứng: G

# %%
#Bài 4
c = input("Nhập một ký tự: ")
if c.isalpha():
        print(f"{c} là ký tự alphabet.")
else:
        print(f"{c} không phải là ký tự alphabet.")
# Out:
# j là ký tự alphabet.

# %%
#Bài 5
c = input("Nhập chữ cái hoa (A-Z): ")
if c == 'A':
    print("Không có chữ cái thường liền trước a.")
elif 'A' < c <= 'Z':
    c_thuong = chr(ord(c.lower()) - 1)
    print(f"Chữ cái thường liền trước là: {c_thuong}")
else:
    print("Ký tự nhập vào không hợp lệ.")
# Out:
# Chữ cái thường liền trước là: c

# %%
#Bài 6
import math
a, b, c = map(float, input("Nhap vao 3 so: ").split())
if a+b>c and b+c>a and a+c>b:
    p=(a+b+c)/2
    s=math.sqrt(p*(p-a)*(p-b)*(p-c))
    print(s)
else:
    print("Khong phai 3 canh cua tam giac")
# Out:
# Khong phai 3 canh cua tam giac

# %%
#Bài 7
s = input("Nhập chuỗi ký tự thường (>=20 ký tự): ")
if len(s) >= 9:
        print("Ký tự thứ 5:", s[4])
        print("Ký tự thứ 9:", s[8])
else:
        print("Chuỗi quá ngắn!")
# Out:
# Ký tự thứ 5: r
# Ký tự thứ 9: n

# %%
#Bài 8
c=input("Nhap ten chu ho: ")
so1=int(input("Nhap vao so dien thang truoc: "))
so2=int(input("Nhap vao so dien thang nay: "))
so=so2 - so1
if 0 <= so <= 50:
    tien = (so*1984)*1.08
    print("Ho va ten: ", c)
    print("Tien phai tra la: ", int(tien))
if 51 <= so <= 100:
    tien = (so*2050)*1.08
    print("Ho va ten: ", c)
    print("Tien phai tra la: ", int(tien))
if 101 <= so <= 200:
    tien = (so*2380)*1.08
    print("Ho va ten: ", c)
    print("Tien phai tra la: ", int(tien))
if 201 <= so <= 300:
    tien = (so*2998)*1.08
    print("Ho va ten: ", c)
    print("Tien phai tra la: ", int(tien))
if 301 <= so <= 400:
    tien = (so*3350)*1.08
    print("Ho va ten: ", c)
    print("Tien phai tra la: ", int(tien))
if so >= 401:
    tien = (so*3460)*1.08
    print("Ho va ten: ", c)
    print("Tien phai tra la: ", int(tien))
# Out:
# Ho va ten:  Hong
# Tien phai tra la:  676708
